# %%
import numpy as np
import pandas as pd 
import matplotlib.pylab as plt
import scipy.io 

file = '../data/vowels.mat'
mat_file = scipy.io.loadmat(file)

# %%
mat_file['X'].shape
# Out:
# (1456, 12)

# %%
y= mat_file['y']

# %%
data = pd.DataFrame(mat_file['X'])

# %%
data['y']=y

# %%
data['y'].value_counts()
# Out:
# 0.0    1406
# 1.0      50
# Name: y, dtype: int64

# %%
data
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.580469 -0.902534  0.617899 -0.997942 -2.463799 -0.846455  2.349849
# 1     0.784375 -1.077366  0.615781 -0.921911 -2.388553 -0.638047  2.106684
# 2     0.791292 -1.086242  0.669773 -0.806112 -2.260781 -0.538491  2.053282
# 3     1.217306 -1.083425  0.855483 -0.724879 -2.155552 -0.101879  1.768597
# 4     1.065352 -1.030178  0.773297 -0.452289 -1.955907  0.248205  1.530474
# ...        ...       ...       ...       ...       ...       ...       ...
# 1451  0.286951  0.898280  0.898001 -0.489441 -0.127830 -0.674159  0.506261
# 1452  1.229374  0.371318  0.507031  0.439482  0.449693  0.048680 -0.187676
# 1453  0.947076  0.358108  0.274725  0.167539 -0.359012 -0.794370  0.628138
# 1454  1.584851  0.693591 -0.375686 -0.050666 -1.736406  1.188949  0.094049
# 1455  2.327350  0.382814  0.775907 -1.671378 -0.530324 -1.406607 -2.396201
#
#              7         8         9        10        11    y
# ...

# %%
data.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_09939_row0_col0, #T_09939_row0_col1, #T_09939_row0_col2, #T_09939_row0_col3, #T_09939_row0_col4, #T_09939_row0_col5, #T_09939_row0_col6, #T_09939_row0_col7, #T_09939_row0_col8, #T_09939_row0_col9, #T_09939_row0_col10, #T_09939_row0_col11, #T_09939_row0_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# ...

# %%
data.to_csv('../data/data_1.csv',index=False)
